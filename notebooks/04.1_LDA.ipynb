# %% [markdown]
# # Linear discriminant analysis

# %%
import pandas as pd
import sys 
sys.path.append("..")
from src.models.LDA.lda import run_lda_diagnostics

# %%
selected_features = [
    "time",
    "age_centered",
    "ejection_fraction_centered",
    "sodium_creatinine_interaction",
]

df = pd.read_csv("../data/processed/heart_failure_clinical_records_dataset_processed.csv")

results = run_lda_diagnostics(
    df=df,
    features=selected_features,
    target="DEATH_EVENT",
    test_size=0.2,
    random_state=42,
)
