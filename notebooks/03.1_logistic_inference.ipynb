# %% [markdown]
# # Logistic regression 1

# %% [markdown]
# ## Inferential models
# **What variables are associated with the event?**
#
# ### Baseline model

# %%
import sys
sys.path.append("../src")
from models.logistic.baseline_logistic import baseline_logistic, baseline_logistic_fe

# %% [markdown]
# #### Raw data model

# %%
baseline_raw_model = baseline_logistic()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.367147
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:            DEATH_EVENT   No. Observations:                  299
# Model:                          Logit   Df Residuals:                      286
# Method:                           MLE   Df Model:                           12
# Date:                Wed, 18 Mar 2026   Pseudo R-squ.:                  0.4151
# Time:                        21:50:33   Log-Likelihood:                -109.78
# converged:                       True   LL-Null:                       -187.67
# Covariance Type:            nonrobust   LLR p-value:                 3.771e-27
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                       10.1849      5.657      1.801      0.072      -0.902      21.272
# age                          0.0474      0.016      3.001      0.003       0.016       0.078
# anaemia                     -0.0075      0.360     -0.021      0.983      -0.714       0.699
# creatinine_phosphokinase     0.0002      0.000      1.249      0.212      -0.000       0.001
# diabetes                     0.1451      0.351      0.413      0.679      -0.543       0.833
# ejection_fraction           -0.0767      0.016     -4.695      0.000      -0.109      -0.045
# high_blood_pressure         -0.1027      0.359     -0.286      0.775      -0.806       0.600
# platelets                  -1.2e-06   1.89e-06     -0.635      0.525    -4.9e-06     2.5e-06
# serum_creatinine             0.6661      0.181      3.670      0.000       0.310       1.022
# serum_sodium                -0.0670      0.040     -1.686      0.092      -0.145       0.011
# sex                         -0.5337      0.414     -1.289      0.197      -1.345       0.278
# smoking                     -0.0135      0.413     -0.033      0.974      -0.822       0.795
# time                        -0.0210      0.003     -6.981      0.000      -0.027      -0.015
# ============================================================================================

# %% [markdown]
# #### Feature engineered

# %%
baseline_processed_model = baseline_logistic_fe()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.352119
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:            DEATH_EVENT   No. Observations:                  299
# Model:                          Logit   Df Residuals:                      281
# Method:                           MLE   Df Model:                           17
# Date:                Wed, 18 Mar 2026   Pseudo R-squ.:                  0.4390
# Time:                        21:50:33   Log-Likelihood:                -105.28
# converged:                       True   LL-Null:                       -187.67
# Covariance Type:            nonrobust   LLR p-value:                 3.026e-26
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                                10.9014      5.650      1.929      0.054      -0.173      21.976
# anaemia                              -0.0241      0.376     -0.064      0.949      -0.762       0.713
# diabetes                             -0.9928      2.175     -0.456      0.648      -5.256       3.270
# high_blood_pressure                  -0.1442      0.389     -0.370      0.711      -0.907       0.619
# platelets                          -1.48e-06   1.95e-06     -0.758      0.449   -5.31e-06    2.35e-06
# serum_sodium                         -0.0404      0.043     -0.949      0.342      -0.124       0.043
# sex                                  -0.5672      0.427     -1.328      0.184      -1.404       0.270
# smoking                               0.1197      0.430      0.278      0.781      -0.724       0.963
# time                                 -0.0211      0.003     -6.868      0.000      -0.027      -0.015
# creatinine_log                       -2.5429      2.179     -1.167      0.243      -6.814       1.728
# age_centered                          0.0403      0.020      1.982      0.048       0.000       0.080
# ejection_fraction_centered           -0.1103      0.025     -4.374      0.000      -0.160      -0.061
# creatinine_phosphokinase_centered     0.0001      0.000      0.575      0.565      -0.000       0.000
# cpk_ejection                       1.949e-05   2.19e-05      0.890      0.374   -2.34e-05    6.24e-05
# age_ejection_interaction              0.0017      0.002      1.123      0.261      -0.001       0.005
# ejection_creatinine_interaction       0.0167      0.008      2.108      0.035       0.001       0.032
# age_diabetes_interaction              0.0188      0.034      0.544      0.586      -0.049       0.086
# sodium_creatinine_interaction        -0.0310      0.019     -1.634      0.102      -0.068       0.006
# =====================================================================================================

# %% [markdown]
# ### Feature selection
# #### Backward selection based on p-values

# %%
from models.logistic.feature_selection import backward_selection, backward_selection_fe

# %%
# Backward selection on raw features.
backward_raw_model = backward_selection()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.367147
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.367148
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.367150
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.367286
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.367579
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.368255
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.371312
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.373723
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.378430
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.379002
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:            DEATH_EVENT   No. Observations:                  299
# Model:                          Logit   Df Residuals:                      295
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 18 Mar 2026   Pseudo R-squ.:                  0.3962
# Time:                        21:50:33   Log-Likelihood:                -113.32
# converged:                       True   LL-Null:                       -187.67
# Covariance Type:            nonrobust   LLR p-value:                 5.012e-32
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# age                   0.0500      0.010      5.106      0.000       0.031       0.069
# ejection_fraction    -0.0717      0.015     -4.938      0.000      -0.100      -0.043
# serum_creatinine      0.7304      0.175      4.185      0.000       0.388       1.073
# time                 -0.0201      0.003     -7.314      0.000      -0.026      -0.015
# =====================================================================================

# %%
# Backward selection with engineered features.
backward_processed_model = backward_selection_fe()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.352119
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.352126
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.352267
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.352527
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.352832
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.353359
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.354091
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.355060
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.356805
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.358681
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.360775
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.363172
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.367265
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.372830
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:            DEATH_EVENT   No. Observations:                  299
# Model:                          Logit   Df Residuals:                      294
# Method:                           MLE   Df Model:                            4
# Date:                Wed, 18 Mar 2026   Pseudo R-squ.:                  0.4060
# Time:                        21:50:33   Log-Likelihood:                -111.48
# converged:                       True   LL-Null:                       -187.67
# Covariance Type:            nonrobust   LLR p-value:                 6.239e-32
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                             3.5776      0.627      5.708      0.000       2.349       4.806
# time                             -0.0204      0.003     -7.198      0.000      -0.026      -0.015
# age_centered                      0.0349      0.015      2.310      0.021       0.005       0.064
# ejection_fraction_centered       -0.0653      0.015     -4.217      0.000      -0.096      -0.035
# sodium_creatinine_interaction    -0.0184      0.004     -4.310      0.000      -0.027      -0.010
# =================================================================================================
