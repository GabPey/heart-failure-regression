# %% [markdown]
# # Logistic regression 1

# %% [markdown]
# ## Inferential models
# **What variables are associated with the event?**
#
# ### Baseline model

# %%
import sys
sys.path.append("../src")
from models.baseline_logistic import baseline_logistic, baseline_logistic_fe

# %% [markdown]
# #### Raw data model

# %%
baseline_raw_model = baseline_logistic()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.367147
#          Iterations 7
#                            Logit Regression Results
# ...
# Dep. Variable:            DEATH_EVENT   No. Observations:                  299
# Model:                          Logit   Df Residuals:                      286
# Method:                           MLE   Df Model:                           12
# Date:                Sun, 15 Mar 2026   Pseudo R-squ.:                  0.4151
# Time:                        20:44:24   Log-Likelihood:                -109.78
# converged:                       True   LL-Null:                       -187.67
# Covariance Type:            nonrobust   LLR p-value:                 3.771e-27
# ...
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# #### Feature engineered

# %%
baseline_processed_model = baseline_logistic_fe()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.353348
#          Iterations 7
#                            Logit Regression Results
# ...
# Dep. Variable:            DEATH_EVENT   No. Observations:                  299
# Model:                          Logit   Df Residuals:                      282
# Method:                           MLE   Df Model:                           16
# Date:                Sun, 15 Mar 2026   Pseudo R-squ.:                  0.4371
# Time:                        20:44:24   Log-Likelihood:                -105.65
# converged:                       True   LL-Null:                       -187.67
# Covariance Type:            nonrobust   LLR p-value:                 1.291e-26
# ...
#                                       coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Only *ejection_creatinine_interaction* resulted interesting.

# %% [markdown]
# ### Feature selection
# #### Backward selection based on p-values

# %%
from models.feature_selection import backward_selection, backward_selection_fe

# %%
# Backward selection on raw features.
backward_raw_model = backward_selection()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.367147
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.367148
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.367150
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.367286
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.367579
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.368255
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.371312
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.373723
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.378430
#          Iterations 7
# ...

# %%
# Backward selection with engineered features.
backward_processed_model = backward_selection_fe()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.353348
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.353357
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.353470
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.353629
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.353916
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.354365
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.355194
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.356990
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.358989
#          Iterations 7
# ...
